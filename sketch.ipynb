# %% [markdown]
# # Building Web-based Analysis & Simulation Platforms with React, Flask, Celery, Bokeh, and Numpy
# ## James Powell

# %% [markdown]
# ## http://bit.ly/dutc-tutorial

# %%
from numpy import sqrt, linspace
from numpy.random import uniform

from bokeh.plotting import figure
from bokeh.io import show, output_notebook

from IPython.display import display_latex, display

output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="21dee830-d87f-4b31-8111-3cd74b4e9cb3">Loading BokehJS ...</span>
#     </div>

# %%
xs = linspace(0, 1, 1000)
ys = sqrt(1 - xs **2)

SIZE = 100000

pts = uniform(0, 1, size=(SIZE, 2))
inside = pts[:,0] ** 2 + pts[:,1] ** 2 < 1

pi = sum(inside) / SIZE * 4

fig = figure()
fig.line(xs, ys, color='blue')
fig.scatter(pts[inside][:,0], pts[inside][:,1], color='blue')
fig.scatter(pts[~inside][:,0], pts[~inside][:,1], color='red')

display_latex(r'$$ \pi \approx {} $$'.format(pi), raw=True)
show(fig)
# Out:
# $$ \pi \approx 3.13772 $$
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="0d2bbd80-fb42-4af4-b585-7b5478e8b010"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("0d2bbd80-fb42-4af4-b585-7b5478e8b010");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("0d2bbd80-fb42-4af4-b585-7b5478e8b010");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '0d2bbd80-fb42-4af4-b585-7b5478e8b010' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"d7ff8c26-8bdf-4fed-965a-172aa09ac6ea":{"roots":{"references":[{"attributes":{"data_source":{"id":"82cfa132-44d3-457e-b0c2-fe89214b792e","type":"ColumnDataSource"},"glyph":{"id":"0aa147b2-4900-4d9d-ad2a-51d03a93f254","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"1fe0c4a8-271c-4dd1-bfad-33394acd7686","type":"Circle"},"selection_glyph":null,"view":{"id":"86770a1b-52f4-4c57-93c5-459b5582397a","type":"CDSView"}},"id":"5de433a8-22e9-45a5-bf11-c75339a245de","type":"GlyphRenderer"},{"attributes":{},"id":"c5feea35-4e94-4bd0-a10a-d75bb3b0df60","type":"BasicTickFormatter"},{"attributes":{"source":{"id":"171d2bc9-dc88-4294-bba5-2c1a8bcd46fa","type":"ColumnDataSource"}},"id":"1738d7a5-be2b-48fe-9fa5-aaffd7db4104","type":"CDSView"},{"attributes":{"plot":null,"text":""},"id":"8c67983e-6d31-4df4-b707-80a569854a4e","type":"Title"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"1fe0c4a8-271c-4dd1-bfad-33394acd7686","type":"Circle"},{"attributes":{"source":{"id":"32d96de7-444f-47f8-949b-3ae83ffbbb74","type":"ColumnDataSource"}},"id":"5c094abb-ebb6-41b7-bc68-f4f6ee86b5b3","type":"CDSView"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[21557]},"y":{"__ndarray__":"...","dtype":"float64","shape":[21557]}}},"id":"32d96de7-444f-47f8-949b-3ae83ffbbb74","type":"ColumnDataSource"},{"attributes":{"fill_color":{"value":"blue"},"line_color":{"value":"blue"},"x":{"field":"x"},"y":{"field":"y"}},"id":"0aa147b2-4900-4d9d-ad2a-51d03a93f254","type":"Circle"},{"attributes":{"source":{"id":"82cfa132-44d3-457e-b0c2-fe89214b792e","type":"ColumnDataSource"}},"id":"86770a1b-52f4-4c57-93c5-459b5582397a","type":"CDSView"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"bfab44c0-2533-41a7-9f91-32f025098cf5","type":"PanTool"},{"id":"a5ddc5b2-b32d-44ba-b3c0-666a6c3801cd","type":"WheelZoomTool"},{"id":"43d49e85-ef28-470e-8fcc-776134590ed5","type":"BoxZoomTool"},{"id":"b1a20fe8-2979-485c-a207-fd6bbdaf5508","type":"SaveTool"},{"id":"021720c0-8b8f-414f-ba6c-ebf1cb8fa6bc","type":"ResetTool"},{"id":"d28d84d4-43a0-41b1-b46a-522e153e5c56","type":"HelpTool"}]},"id":"3a591e3c-c545-4a59-b285-206a74b562eb","type":"Toolbar"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"1341187b-c019-4d46-b880-2da4e4a9fd75","type":"Line"},{"attributes":{"below":[{"id":"cc5bb34b-ae3e-4533-a926-cf6faa4ee043","type":"LinearAxis"}],"left":[{"id":"1404553d-088a-40de-b6d6-cf997da82bee","type":"LinearAxis"}],"renderers":[{"id":"cc5bb34b-ae3e-4533-a926-cf6faa4ee043","type":"LinearAxis"},{"id":"352b480a-365d-4a3c-b8b0-54fe9a6b3ad7","type":"Grid"},{"id":"1404553d-088a-40de-b6d6-cf997da82bee","type":"LinearAxis"},{"id":"042fc8fd-a448-4626-bc02-0cb93593b776","type":"Grid"},{"id":"fed2872f-3ea9-40bc-8821-96f37eaba2b9","type":"BoxAnnotation"},{"id":"82eda7b6-33b3-437a-8915-75255462fdac","type":"GlyphRenderer"},{"id":"5de433a8-22e9-45a5-bf11-c75339a245de","type":"GlyphRenderer"},{"id":"42db99d4-4ecd-4a04-987c-9978492d6cdd","type":"GlyphRenderer"}],"title":{"id":"8c67983e-6d31-4df4-b707-80a569854a4e","type":"Title"},"toolbar":{"id":"3a591e3c-c545-4a59-b285-206a74b562eb","type":"Toolbar"},"x_range":{"id":"d9b06336-62b2-4a1d-9465-d7f47f1dede7","type":"DataRange1d"},"x_scale":{"id":"52ff91f1-ecdc-42ff-876f-40b5dae884d0","type":"LinearScale"},"y_range":{"id":"96ed7f73-79aa-4e9e-b4ec-993dd58775c2","type":"DataRange1d"},"y_scale":{"id":"e0210fe9-19b9-47e7-85fe-5780743b4ac5","type":"LinearScale"}},"id":"5b92fcdc-deec-49ad-957a-e339218eb631","subtype":"Figure","type":"Plot"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[1000]},"y":{"__ndarray__":"...","d ...
